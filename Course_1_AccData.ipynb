# %% [markdown]
# <a href="https://colab.research.google.com/github/sigvehaug/MLwPython/blob/master/Course_1_AccData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # About this Introduction to the Winter School on Deep Learning

# %% [markdown]
# Basic machine learning refreshment with an introduction on how to perform typical machine learning tasks with Python.
#
# PD Dr. Sigve Haug, 2025. https://github.com/sigvehaug/MLwPython
#
# Based on notebooks by Honghong Fang, Mykhailo Vladymyrov & Aris Marcolongo. https://github.com/neworldemancer/DSF5
#
# This work is licensed under <a href="https://creativecommons.org/share-your-work/public-domain/cc0/">CC0</a>.
#
# Duration: 14:00-17:00

# %% [markdown]
# ### Learning outcomes
#
# - Know the basic Machine Learning (ML) vocabulary
# - Know the ML paradigms and tasks
# - Know common performance metrics
# - Know common ML platforms and libraries
# - Can perform basic ML workflows (tutorial)

# %% [markdown]
# # Table of Content

# %% [markdown]
# - ML Context
# - ML Definition
# - ML Tasks
# - ML Performance
# - ML Data
# - ML Platforms and Libraries
# - ML Workflow
# - ML Exercise

# %% [markdown]
# # Machine Learning (ML) in Context

# %% [markdown]
# ### Technological Revolutions

# %% [markdown]
# Societal development may be seen as a process boosted by technological revolutions:
#
# * 10k BC    Agricultural/Neolithic
# * 1760-1840 Industrial
# * 1850-1900 Electromagnetic
# * 1960-2000 Information
# * 2010-     Biocognitive (gene design and artificial and extended intelligence)
#
# AI has a huge automatization potential (already happening). Humans are outsourcing cognitive (brain) tasks. The comprehensive impact on society is hard to foresee. Some scholars even talk about the end of humanity (singularity). When one talks about AI, one normally means machine learning algorithms, e.g. ChatGPT.

# %% [markdown]
# ### Agency, AI and ML

# %% [markdown]
# ![Screenshot 2025-02-18 at 12.41.39.png](data:image/png;base64,...)

# %% [markdown]
# ### In the scientific/data science process we are in the loops of this diagram here:

# %% [markdown]
# ![Screenshot 2025-02-18 at 12.50.35.png](data:image/png;base64,...)

# %% [markdown]
# ### Removing the human from the scientific process

# %% [markdown]
# ![Screenshot 2025-02-18 at 12.51.26.png](data:image/png;base64,...)

# %% [markdown]
# # ML Definition

# %% [markdown]
# Classical algorithms were or are created by humans to analyze data:
#
# ---

# %% [markdown]
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/alg_1.png" width="60%"/>

# %% [markdown]
# in machine learning the data itself is used for to define the algorithm:

# %% [markdown]
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/alg_2.png" width="60%"/>

# %% [markdown]
# A ML definition (Tom Mitchell 1998):
#
# "A computer program is said to learn from experience E with respect to some class of tasks T and performance measure P, if its performance at tasks in T, as measured by P, improves with experience E."

# %% [markdown]
# # ML Paradigms and Tasks

# %% [markdown]
# The typical ML paradigms with some application examples.
#
# <img src="https://github.com/sigvehaug/MLwPython/raw/master/figures/ML-Categories.jpg" width="60%"/>

# %% [markdown]
# ## Classification versus regression
#
# The two main tasks handled by (supervised) ML is regression and classification.
# In regression we aim at modeling the relationship between the system's response (dependent variable) and one or more explanatory variables (independent variables). In regression the output is contineous (real number).
#
# Examples of regression would be predicting the temperature for each day of the year, or expenses of the household as a function of the number of children and adults.
#
# In classification the aim is to identify what class does a data-point belong to. For example, the species or the iris plant based on the size of its petals, or whether an email is spam or not based on its content. In classification the output is a class / an integer.
#
# In this introduction we don't cover clustering and reinforcement learning.

# %% [markdown]
# ## ML Algorithms
#
# ML researchers have designed, tested and implemented tens, hundreds, thousands of ML algorithms. Which one to choose depends on the task, the data and the cost (time, ethics, etc). When doing ML, one needs to briefly know the main categories, which tools/implementations to use and try a few algorithms, fine tune the best and bring it into production for ones task.
#
# A good way to get an overview is just to look at the list of implementations in scikit-learn: https://scikit-learn.org/stable/user_guide.html
#
# This is only one way to make an ML cheet sheet:
#
# <img src="https://github.com/sigvehaug/MLwPython/raw/master/figures/cheatsheet.png" width="60%"/>

# %% [markdown]
# Other cheat-sheets:
# * https://stanford.edu/~shervine/teaching/cs-229/cheatsheet-machine-learning-tips-and-tricks
# * https://github.com/afshinea/stanford-cs-229-machine-learning/blob/master/en/super-cheatsheet-machine-learning.pdf
# * https://s3.amazonaws.com/assets.datacamp.com/email/other/ML+Cheat+Sheet_2.pdf
# * https://learn.microsoft.com/en-us/azure/machine-learning/algorithm-cheat-sheet

# %% [markdown]
# # ML Performance

# %% [markdown]
# ## Overfitting and underfitting
#
# When doing ML, the goal is to achieve maximal performance while the model still generelizes. This is related to under- and overfitting.

# %% [markdown]
# ![Screenshot 2025-02-19 at 10.22.59.png](data:image/png;base64,...)

# %% [markdown]
# Remedy: Training, validation and test set.

# %% [markdown]
# ![Screenshot 2025-02-19 at 10.37.50.png](data:image/png;base64,...)

# %% [markdown]
# ## Training, validation and test data
#
# To measure model performance in an unbiassed way, we need to use different data than the data that the model was trained on. For this we use the 'train-test' split: e.g. 20% of all available dataset is reserved for model performance test, and the remaining 80% is used for actual model training. Often one also use a certain split of the data for validation, or hyper-parameter optimisation.

# %% [markdown]
# ## Performance Measures

# %% [markdown]
# ### Regression:
# The performance metrics for regression tasks are mostly some kind of distance.

# %% [markdown]
# * Mean Square Error: $\textrm{MSE}=\frac{1}{n}\sum_i(y_i - \hat y(\bar x_i))^2$
# * Mean Absolute Error: $\textrm{MAE}=\frac{1}{n}\sum_i|y_i - \hat y(\bar x_i)|$
# * Median Absolute Deviation: $\textrm{MAD}=\textrm{median}(|y_i - \hat y(\bar x_i)|)$
# * Fraction of the explained variance: $R^2=1-\frac{\sum_i(y_i - \hat y(\bar x_i))^2}{\sum_i(y_i - \bar y)^2}$, where $\bar y=\frac{1}{n}\sum_i y_i$

# %% [markdown]
# ### Classification:
# The performance metrics for classification tasks are mostly based on the [Confusion Matrix](https://en.wikipedia.org/wiki/Confusion_matrix). Here an example with two classes:
#
# <img src="https://github.com/neworldemancer/DSF5/raw/master/figures/confusion_mtr.png" width="60%"/>

# %% [markdown]
# * Accuracy $=\frac{\textrm{TP} + \textrm{TN}}{\textrm{TP} + \textrm{FP} + \textrm{FN} + \textrm{TN}}$
# * Precision $=\frac{\textrm{TP}}{\textrm{TP} + \textrm{FP}}$
# * Recall $=\frac{\textrm{TP}}{\textrm{TP} + \textrm{FN}}$
# * F1 $=2\frac{\textrm{Precision} \cdot \textrm{Recall}}{\textrm{Precision} + \textrm{Recall}} = \frac{2 \textrm{TP}}{2 \textrm{TP} + \textrm{FP} + \textrm{FN}}$
# * Threat score (TS), or Intersection over Union: $\mathrm{IoU}=\frac{\mathrm{TP}}{\mathrm{TP}+\mathrm{FN}+\mathrm{FP}}$
#
#
# During model optimization the used measure in most cases must be differentiable. To this end usually some measure of similarities of distributions are employed (e.g. cross-entropy).

# %% [markdown]
# # ML Data / Experience

# %% [markdown]
# Data is any set of symbols. For the current ML tools (Python scikit-lear, tensorflow, pytorch, etc) data must be numbers in a table (dataframe), one, two, or higher dimensional (tensor). So any data, like images, videos, sound, text ... must be turned into a table before processeing it with ML. Cleaning and preprocessing data into these tables are the normally the most time consuming part in data science and ML projects.
#
# If the data is a sequence (ordered list), methods need to take the order into account. Nowadays transformer models are much used for sequences.
#
# And, if your data is rubbish, the results will be rubbish, too.

# %% [markdown]
# # ML Platforms and Libraries

# %% [markdown]
# Very good software libraries, large computing (GPU) and data resources have made big scale ML possible. The main libraries are:
#
# - scikit-learn from the Python community, rich and good for smaller things
# - PyTorch started from Meta, very much favoured and good for deeplearning
# - TensorFlow started from Google, also good for deeplearning
#
# Today we will use the scikit-learn module. You can find extensive documentation with examples in the user guide. Tomorrow we continue with PyTorch. There are ML libraries also for R, MATLAB etc, however, normally not the first choice in the community.
#
# There are different environments for developing and running (ML) code.
#
# - Jupyter notebooks in the cloud, normally on google colab. No local installations, good for teaching and smaller projects.
# - Jupyter notebooks locally on own machine, normally installed with Anaconda.
# - Locally installed Integrated Development Environment (IDE), e.g. Visual Studio, Spyder ..., a must for daily developers doing larger projects
#
# Normally code is kept and tracked on a git repository, either on GitHub or some on premise installation of GitLab. Further there is the community platform  with datasets, models, spaces for easy running of ML apps and code repositories.
#
# - HuggingFace Hub
# - OpenAI, StationF, Kaggle

# %% [markdown]
# # ML Workflow

# %% [markdown]
# - Define your task (classification, regression) and your data model
# - Collect your data (quality, amount, ...)
# - Preprocess your data (cleaning, filtering, feature engineering, ...)
# - Choose, train and assess your model till you are happy, e.g. log. reg., random forrest and FCNN
# - Publish / enter production

# %% [markdown]
# # ML Exercise

# %% [markdown]
# In this exercise, we will collect accelerator data with our smartphones for two different movements/classes.

# %% [markdown]
# ### Data Collection

# %% [markdown]
# - Install the free phyphox app on your phone
# - Choose Acceleration without g
# - Start data taking, walk up and down in the room for about 30s while keeping your phone in one hand
# - Stop data taking and export the data as csv to your computer (via signal or mail or something else)
# - Delete your data on the phone
# - Repeat the 3 last steps but now jumping up and down
# - Rename and upload the two datasets to your google drive. The names may contain "walk" and "jump".

# %% [markdown]
# ## Load and inspect dataset (exploratory data analysis)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l drive/MyDrive/Courses/
# Out:
# total 28
# drwx------ 2 root root 4096 Apr 24  2022 Business-Concept-22
# drwx------ 2 root root 4096 Nov 23  2021 DA-Vis-Python-VR
# drwx------ 2 root root 4096 Mar 19  2024 DSF-DCBP
# drwx------ 2 root root 4096 Nov 15 11:12 DSL-AICS
# drwx------ 2 root root 4096 Dec 24  2022 ML4TS
# drwx------ 2 root root 4096 Sep  1  2021 Python4Medicine
# drwx------ 2 root root 4096 Jan  3  2024 WS-DL-2024

# %%
# !ls -l ./drive/MyDrive/Courses/WS-DL-2024/
# Out:
# total 7712
# -rw------- 1 root root  179714 Feb 26  2024  boxing.csv
# -rw------- 1 root root  516549 Feb 26  2024  BWS-2024-ML-Refresher.ipynb
# -rw------- 1 root root     175 Feb 13  2024  BWSDL-2024-Feedback.gform
# -rw------- 1 root root     175 Feb 12  2024  BWS-DL-2024-Projects.gdoc
# -rw------- 1 root root  294640 Jan 14  2024  BWSML-DL-FB-2024.pdf
# -rw------- 1 root root  267578 Jan  5  2024  Data-Jump.csv
# -rw------- 1 root root  252899 Jan  5  2024  Data-Walk.csv
# -rw------- 1 root root 4050049 Mar 27  2024  Lecture2_MV_2024.pdf
# -rw------- 1 root root     175 Feb 26  2024  ML-Brushup-BWSML-24.gslides
# -rw------- 1 root root 1983421 Jan  3  2024 'movement 1.ipynb'
# -rw------- 1 root root  347370 Feb 26  2024  walk.csv
# -rw------- 1 root root     175 Jan  5  2024  WS-DL-Classification-Champion.gform
# -rw------- 1 root root     175 Mar 13  2024  WS-NLP-FB-2024.gform
# -rw------- 1 root root     175 Mar  1  2024  WS-RL-FB-2024.gform

# %%
import pandas as pd
dataset1 = './drive/MyDrive/Courses/WS-DL-2024/Data-Walk.csv'
dataset2 = './drive/MyDrive/Courses/WS-DL-2024/Data-Jump.csv'

movement1 = pd.read_csv(dataset1)
movement2 = pd.read_csv(dataset2)

# Add the target column

movement1['type'] = 'walk'
movement2['type'] = 'jump'

movement = pd.concat([movement1, movement2])
movement
# Out:
#        Time (s)  Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# 0      0.008433                      -0.439448                       0.298613
# 1      0.018430                      -0.593483                       0.407320
# 2      0.028427                      -0.642879                       0.395847
# 3      0.038424                      -0.582221                       0.375405
# 4      0.048420                      -0.449434                       0.322077
# ...         ...                            ...                            ...
# 3717  37.161753                      -0.932274                      -0.165263
# 3718  37.171750                      -0.600473                      -0.040368
# 3719  37.181747                      -0.401486                       0.058877
# 3720  37.191744                      -0.362165                       0.068498
# 3721  37.201742                      -0.190517                       0.121572
#
# ...

# %%
# @title type vs Linear Acceleration x (m/s^2)

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(movement['type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(movement, x='Linear Acceleration x (m/s^2)', y='type', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-11-3e212317b80d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(movement, x='Linear Acceleration x (m/s^2)', y='type', inner='box', palette='Dark2')

# %%
movement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7210 entries, 0 to 3721
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Time (s)                       7210 non-null   float64
#  1   Linear Acceleration x (m/s^2)  7210 non-null   float64
#  2   Linear Acceleration y (m/s^2)  7210 non-null   float64
#  3   Linear Acceleration z (m/s^2)  7210 non-null   float64
#  4   Absolute acceleration (m/s^2)  7210 non-null   float64
#  5   type                           7210 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 394.3+ KB

# %%
movement[movement['type']=='walk'].describe()
# Out:
#           Time (s)  Linear Acceleration x (m/s^2)  \
# count  3488.000000                    3488.000000
# mean     17.437839                      -1.842839
# std      10.067228                       3.438485
# min       0.008433                     -12.956445
# 25%       8.723109                      -4.199794
# 50%      17.437808                      -1.522803
# 75%      26.152563                       0.691644
# max      34.867337                       4.964561
#
#        Linear Acceleration y (m/s^2)  Linear Acceleration z (m/s^2)  \
# count                    3488.000000                    3488.000000
# mean                       -1.030089                       0.676618
# std                         4.997458                       2.022738
# min                       -11.630022                      -4.449532
# 25%                        -5.298654                      -0.582751
# 50%                        -0.683178                       0.580202
# ...

# %%
movement[movement['type']=='jump'].describe()
# Out:
#           Time (s)  Linear Acceleration x (m/s^2)  \
# count  3722.000000                    3722.000000
# mean     18.602180                      -0.324674
# std      10.742775                      13.446117
# min       0.002683                     -43.175709
# 25%       9.302404                      -6.659895
# 50%      18.602170                       5.228132
# 75%      27.901945                       9.907926
# max      37.201742                      15.406604
#
#        Linear Acceleration y (m/s^2)  Linear Acceleration z (m/s^2)  \
# count                    3722.000000                    3722.000000
# mean                       -0.434065                      -0.109990
# std                         7.970701                       3.630438
# min                       -27.558919                      -7.466704
# 25%                        -3.681464                      -2.489153
# 50%                         2.740235                      -0.579801
# ...

# %% [markdown]
# ### Visualize

# %%
sns.scatterplot(data=movement, x='Linear Acceleration x (m/s^2)',
                y='Linear Acceleration z (m/s^2)', hue='type');

# %%
sns.scatterplot(data=movement, x='Linear Acceleration x (m/s^2)',
                y='Linear Acceleration y (m/s^2)', hue='type');

# %%
sns.scatterplot(data=movement, x='Linear Acceleration y (m/s^2)',
                y='Linear Acceleration z (m/s^2)', hue='type');

# %% [markdown]
# ### Clean and split the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

# %%
training = movement.drop(columns=['Time (s)'])
train, test = train_test_split(training, train_size=0.8)
print(train.shape, test.shape)
train
# Out:
# (5768, 5) (1442, 5)
#       Linear Acceleration x (m/s^2)  Linear Acceleration y (m/s^2)  \
# 1199                      -4.951682                       1.246171
# 1019                      -6.275334                       0.751450
# 2690                      -8.636971                       4.351960
# 3312                      10.394340                       1.196596
# 2043                       0.791450                      -7.545452
# ...                             ...                            ...
# 2005                      -7.885263                       0.997202
# 1787                      -0.094317                       0.177039
# 1683                       7.965448                       6.452006
# 1004                      10.213150                       7.373129
# 1909                      -0.925750                      -0.422158
#
#       Linear Acceleration z (m/s^2)  Absolute acceleration (m/s^2)  type
# ...

# %% [markdown]
# ## Train and Evaluate Models

# %% [markdown]
# Here we try two different models and check for overfitting.

# %%
X   = train.drop(columns='type')
y   = train['type']

model = LogisticRegression()
#model = RandomForestClassifier(max_depth=12, random_state=0)
model.fit(X, y)

print(confusion_matrix(train['type'],model.predict(X=train.drop(columns='type'))))
print(confusion_matrix(test['type'], model.predict(X=test.drop(columns='type'))))
print(classification_report(test['type'], model.predict(X=test.drop(columns='type'))))
print(classification_report(train['type'], model.predict(X=train.drop(columns='type'))))
# Out:
# [[2254  708]
#  [ 348 2458]]
# [[581 179]
#  [ 82 600]]
#               precision    recall  f1-score   support
#
#         jump       0.88      0.76      0.82       760
#         walk       0.77      0.88      0.82       682
#
#     accuracy                           0.82      1442
#    macro avg       0.82      0.82      0.82      1442
# weighted avg       0.83      0.82      0.82      1442
#
#               precision    recall  f1-score   support
#
#         jump       0.87      0.76      0.81      2962
#         walk       0.78      0.88      0.82      2806
#
#     accuracy                           0.82      5768
#    macro avg       0.82      0.82      0.82      5768
# weighted avg       0.82      0.82      0.82      5768

# %%
print(confusion_matrix(test['type'], model.predict(X=test.drop(columns='type'))))
print(classification_report(test['type'], model.predict(X=test.drop(columns='type'))))

# %% [markdown]
# In teams of 4, think of ways to improve your classification, do it and publish your accuracy [here](https://docs.google.com/forms/d/e/1FAIpQLSfTODp5uhppXiCnYwQdEGxaUQdshr2H6jdQ0sDE7oe5Be4ulw/viewform?usp=sf_link).

# %% [markdown]
# Think of other useful classification tasks you could do with phones.

# %% [markdown]
# # The Rest of the Winter School

# %% [markdown]
# Now we have seen how to use the Python library scikit-learn for ML. Tomorrow and the rest of the week, you will learn about deep neural networks and use PyTorch to perform ML. TensorFlow is an alternative to PyTorch.
